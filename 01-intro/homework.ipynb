# %% [markdown]
# **Q1. Pandas version**

# %%
import pandas as pd
import numpy as np

# What's the version of Pandas that you installed?

pd.__version__
# Out:
# '2.3.1'

# %% [markdown]
# **Getting the data**

# %%
# # reading data 
data = pd.read_csv("https://raw.githubusercontent.com/alexeygrigorev/datasets/master/car_fuel_efficiency.csv")
data
# Out:
#       engine_displacement  num_cylinders  horsepower  vehicle_weight  \
# 0                     170            3.0       159.0     3413.433759
# 1                     130            5.0        97.0     3149.664934
# 2                     170            NaN        78.0     3079.038997
# 3                     220            4.0         NaN     2542.392402
# 4                     210            1.0       140.0     3460.870990
# ...                   ...            ...         ...             ...
# 9699                  140            5.0       164.0     2981.107371
# 9700                  180            NaN       154.0     2439.525729
# 9701                  220            2.0       138.0     2583.471318
# 9702                  230            4.0       177.0     2905.527390
# 9703                  270            3.0       140.0     2908.043477
#
#       acceleration  model_year  origin fuel_type         drivetrain  \
# 0             17.7        2003  Europe  Gasoline    All-wheel drive
# ...

# %% [markdown]
# **Q2. Records count**

# %%
# How many records are in the dataset?

f'number of records: {len(data)}'
# Out:
# 'number of records: 9704'

# %% [markdown]
# **Q3. Fuel types**

# %%
# How many fuel types are presented in the dataset?
f'Types of Fuel: {len(data.fuel_type.unique())}'
# Out:
# 'Types of Fuel: 2'

# %% [markdown]
# **Q4. Missing values**

# %%
# How many columns in the dataset have missing values? 
missingValues = data.isnull().sum() > 0
f'Number of Missing columns having missing values: {len(missingValues[missingValues == True])}'
# Out:
# 'Number of Missing columns having missing values: 4'

# %% [markdown]
# **Q5. Max fuel efficiency**

# %%
# What's the maximum fuel efficiency of cars from Asia? 

f'Maximum fuel efficiency of Asia: {data[data.origin == 'Asia'].fuel_efficiency_mpg.max()}'
# Out:
# 'Maximum fuel efficiency of Asia: 23.759122836520497'

# %% [markdown]
# **Q6. Median value of horsepower**

# %%
# Find the median value of horsepower column in the dataset.

f"Median value of horsepower: {data.horsepower.median()}"
# Out:
# 'Median value of horsepower: 149.0'

# %%
# Next, calculate the most frequent value of the same horsepower column.
f"Most frequent value of horsepower(MODE): {data.horsepower.mode()[0]}"
# Out:
# 'Most frequent value of horsepower(MODE): 152.0'

# %%
# Use fillna method to fill the missing values in horsepower column with the most frequent value from the previous step.
f"missing values in horsepower column: {data.horsepower.fillna(0).median()}"
# Out:
# 'missing values in horsepower column: 146.0'

# %%
# Now, calculate the median value of horsepower once again.

f"Median value of horsepower: {data.horsepower.median()}"
# Out:
# 'Median value of horsepower: 149.0'

# %% [markdown]
# **Q7. Sum of weights**

# %% [markdown]
# ****1. Select all the cars from Asia****

# %%
data[data['origin'] == 'Asia']
# Out:
#       engine_displacement  num_cylinders  horsepower  vehicle_weight  \
# 8                     250            1.0       174.0     2714.219310
# 12                    320            5.0       145.0     2783.868974
# 14                    200            6.0       160.0     3582.687368
# 20                    150            3.0       197.0     2231.808142
# 21                    160            4.0       133.0     2659.431451
# ...                   ...            ...         ...             ...
# 9688                  260            4.0         NaN     3948.404625
# 9692                  180            3.0       188.0     3680.341381
# 9693                  280            2.0       148.0     2545.070139
# 9698                  180            1.0       131.0     3107.427820
# 9703                  270            3.0       140.0     2908.043477
#
#       acceleration  model_year origin fuel_type         drivetrain  num_doors  \
# ...

# %% [markdown]
# ****2. Select only columns vehicle_weight and model_year****

# %%
data[['vehicle_weight', 'model_year']]
# Out:
#       vehicle_weight  model_year
# 0        3413.433759        2003
# 1        3149.664934        2007
# 2        3079.038997        2018
# 3        2542.392402        2009
# 4        3460.870990        2009
# ...              ...         ...
# 9699     2981.107371        2013
# 9700     2439.525729        2004
# 9701     2583.471318        2008
# 9702     2905.527390        2011
# 9703     2908.043477        2005
#
# [9704 rows x 2 columns]

# %% [markdown]
# ****3. Select the first 7 values****

# %%
data.head(7)
# Out:
#    engine_displacement  num_cylinders  horsepower  vehicle_weight  \
# 0                  170            3.0       159.0     3413.433759
# 1                  130            5.0        97.0     3149.664934
# 2                  170            NaN        78.0     3079.038997
# 3                  220            4.0         NaN     2542.392402
# 4                  210            1.0       140.0     3460.870990
# 5                  190            3.0         NaN     2484.883986
# 6                  240            7.0       127.0     3006.542287
#
#    acceleration  model_year  origin fuel_type         drivetrain  num_doors  \
# 0          17.7        2003  Europe  Gasoline    All-wheel drive        0.0
# 1          17.8        2007     USA  Gasoline  Front-wheel drive        0.0
# 2          15.1        2018  Europe  Gasoline  Front-wheel drive        0.0
# 3          20.2        2009     USA    Diesel    All-wheel drive        2.0
# ...
